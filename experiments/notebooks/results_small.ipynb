# %% [markdown]
# # Notebook for analyzing the results

# %% [markdown]
# In this notebook we analyze the results from the experiments we ran.

# %%
import json
import pandas as pd
from pathlib import Path
from bnsl.scoring import compute_shd

# %% [markdown]
# Store the records as a dataframe

# %%
root = Path.cwd().parents[1]    # two levels up
files = list((root / "data" / "results").rglob("*.json"))

# %%
records = []
for f in files:
    with open(f) as fp:
        r = json.load(fp)
        record = {
            "algorithm": r["algorithm"],
            "network": r["network"].split("/")[-1].split(".")[0],
            "num_samples": r["num_samples"],
            "score": r["score"],
            "theoretical_upper_bound": r["bounds"].get("theoretical_upper_bound"),
            "naive_upper_bound": r["bounds"].get("naive_upper_bound"),
            "runtime": r["seconds_elapsed"],
            "k": r["params"].get("k"),
            "l": r["params"].get("l"),
            "num_vars": r["num_variables"],
            "seed": r["seed"],
            "parent_map": r.get("parent_map"),
        }
        records.append(record)

df = pd.DataFrame(records)

# %%
df.head()
# Out:
#             algorithm network  num_samples      score  \
# 0  silander_myllymaki  survey          100   -423.143
# 1  silander_myllymaki    asia        10000 -22193.508
# 2  silander_myllymaki  survey         1000  -4033.283
# 3  silander_myllymaki  survey        10000 -39569.183
# 4  silander_myllymaki   sachs          100   -869.895
#
#    theoretical_upper_bound  naive_upper_bound  runtime   k   l  num_vars  \
# 0                      NaN           -420.051    0.000 NaN NaN         6
# 1                      NaN         -16725.365    0.003 NaN NaN         8
# 2                      NaN          -4019.411    0.000 NaN NaN         6
# 3                      NaN         -39207.216    0.000 NaN NaN         6
# 4                      NaN           -821.083    0.030 NaN NaN        11
#
#    seed                                         parent_map
# 0    42  {'A': [], 'E': ['A'], 'O': [], 'R': [], 'S': [...
# 1    44  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...
# 2    44  {'A': ['E'], 'E': [], 'O': [], 'R': ['T'], 'S'...
# 3    44  {'A': ['E'], 'E': ['O', 'R'], 'O': ['T'], 'R':...
# 4    42  {'Akt': ['Erk'], 'Erk': [], 'Jnk': ['PKA'], 'M...

# %% [markdown]
#  Create a table with only approximation algorithm, and true fields from dp

# %%
approx_df = df[df["algorithm"] == "approximation_algorithm"].drop(columns=["algorithm"])

# %%
# apply the true score from silander myllymaki to the corresponding approximation results
approx_df["dp_score"] = approx_df.apply(
    lambda row: df[
        (df["algorithm"] == "silander_myllymaki") &
        (df["network"] == row["network"]) &
        (df["num_samples"] == row["num_samples"]) &
        (df["seed"] == row["seed"])
    ]["score"].values[0], axis=1
)

# %%
# apply the true pm from silander myllymaki to the corresponding approximation results
approx_df["dp_parent_map"] = approx_df.apply(
    lambda row: df[
        (df["algorithm"] == "silander_myllymaki") &
        (df["network"] == row["network"]) &
        (df["num_samples"] == row["num_samples"]) &
        (df["seed"] == row["seed"])
    ]["parent_map"].values[0], axis=1
)

# %%
approx_df.head()
# Out:
#        network  num_samples     score  theoretical_upper_bound  \
# 45        asia         1000 -2241.466                11067.515
# 46       sachs         1000 -7629.010                -3373.455
# 47  earthquake          100   -64.285                   45.484
# 48  earthquake         1000  -415.992                  -68.773
# 49      cancer         1000 -2146.611                -1663.531
#
#     naive_upper_bound  runtime    k    l  num_vars  seed  \
# 45          -1707.315    0.003  5.0  1.0         8    44
# 46          -6831.660    0.021  4.0  2.0        11    42
# 47            -61.788    0.001  4.0  2.0         5    44
# 48           -382.674    0.001  3.0  2.0         5    42
# 49          -2129.812    0.001  3.0  2.0         5    42
#
#                                            parent_map  dp_score  \
# 45  {'asia': [], 'bronc': [], 'dysp': ['bronc', 'e... -2235.024
# 46  {'Akt': ['Erk', 'PKA'], 'Erk': ['Mek', 'PKA'],... -7629.010
# 47  {'Alarm': ['JohnCalls'], 'Burglary': ['Alarm']...   -64.285
# 48  {'Alarm': ['Burglary'], 'Burglary': [], 'Earth...  -415.992
# 49  {'Cancer': [], 'Dyspnoea': [], 'Pollution': ['... -2146.611
#
#                                         dp_parent_map
# 45  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...
# 46  {'Akt': ['Erk', 'PKA'], 'Erk': ['Mek'], 'Jnk':...
# 47  {'Alarm': ['JohnCalls'], 'Burglary': ['Alarm']...
# 48  {'Alarm': [], 'Burglary': ['Alarm'], 'Earthqua...
# 49  {'Cancer': [], 'Dyspnoea': [], 'Pollution': ['...

# %% [markdown]
# Compute SHD from the DP network

# %%
approx_df["SHD"] = approx_df.apply(
    lambda row: compute_shd(
        root / "networks" /  "small" / f"{row['network']}.bif",
       row["parent_map"],
    ), axis=1
)

# %%
approx_df.sort_values(["network", "num_samples"]).head(20)
# Out:
#     network  num_samples      score  theoretical_upper_bound  \
# 64     asia          100   -252.923                   66.933
# 65     asia          100   -252.923                   66.933
# 104    asia          100   -252.923                  -92.995
# 105    asia          100   -252.923                  -92.995
# 108    asia          100   -256.725                 1007.490
# 117    asia          100   -256.725                 1007.490
# 130    asia          100   -252.923                  -92.995
# 138    asia          100   -252.923                   66.933
# 176    asia          100   -256.725                 1007.490
# 45     asia         1000  -2241.466                11067.515
# 73     asia         1000  -2238.429                 -573.288
# 84     asia         1000  -2235.024                 1098.663
# 88     asia         1000  -2235.024                 1098.663
# 101    asia         1000  -2238.429                 -573.288
# 116    asia         1000  -2235.024                 1098.663
# 125    asia         1000  -2238.429                 -573.288
# 153    asia         1000  -2241.466                11067.515
# 161    asia         1000  -2241.466                11067.515
# 53     asia        10000 -22202.566               110915.416
# 74     asia        10000 -22193.508                11095.047
#
#      naive_upper_bound  runtime    k    l  num_vars  seed  \
# 64            -205.545    0.003  4.0  2.0         8    43
# 65            -205.545    0.011  4.0  2.0         8    44
# 104           -205.545    0.006  3.0  2.0         8    44
# 105           -205.545    0.005  3.0  2.0         8    43
# 108           -205.545    0.002  5.0  1.0         8    42
# 117           -205.545    0.001  5.0  1.0         8    43
# 130           -205.545    0.006  3.0  2.0         8    42
# 138           -205.545    0.004  4.0  2.0         8    42
# 176           -205.545    0.004  5.0  1.0         8    44
# 45           -1707.315    0.003  5.0  1.0         8    44
# 73           -1707.315    0.005  3.0  2.0         8    43
# 84           -1707.315    0.004  4.0  2.0         8    43
# 88           -1707.315    0.006  4.0  2.0         8    42
# 101          -1707.315    0.011  3.0  2.0         8    44
# 116          -1707.315    0.008  4.0  2.0         8    44
# 125          -1707.315    0.010  3.0  2.0         8    42
# 153          -1707.315    0.002  5.0  1.0         8    43
# 161          -1707.315    0.003  5.0  1.0         8    42
# 53          -16725.365    0.008  5.0  1.0         8    42
# 74          -16725.365    0.005  4.0  2.0         8    43
#
#                                             parent_map   dp_score  \
# 64   {'asia': [], 'bronc': [], 'dysp': ['bronc'], '...   -251.306
# 65   {'asia': [], 'bronc': [], 'dysp': ['bronc'], '...   -251.306
# 104  {'asia': [], 'bronc': ['dysp'], 'dysp': [], 'e...   -251.306
# 105  {'asia': [], 'bronc': ['dysp'], 'dysp': [], 'e...   -251.306
# 108  {'asia': [], 'bronc': [], 'dysp': ['bronc'], '...   -251.306
# 117  {'asia': [], 'bronc': [], 'dysp': ['bronc'], '...   -251.306
# 130  {'asia': [], 'bronc': ['dysp'], 'dysp': [], 'e...   -251.306
# 138  {'asia': [], 'bronc': [], 'dysp': ['bronc'], '...   -251.306
# 176  {'asia': [], 'bronc': [], 'dysp': ['bronc'], '...   -251.306
# 45   {'asia': [], 'bronc': [], 'dysp': ['bronc', 'e...  -2235.024
# 73   {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...  -2235.024
# 84   {'asia': [], 'bronc': [], 'dysp': ['bronc', 'e...  -2235.024
# 88   {'asia': [], 'bronc': [], 'dysp': ['bronc', 'e...  -2235.024
# 101  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...  -2235.024
# 116  {'asia': [], 'bronc': [], 'dysp': ['bronc', 'e...  -2235.024
# 125  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...  -2235.024
# 153  {'asia': [], 'bronc': [], 'dysp': ['bronc', 'e...  -2235.024
# 161  {'asia': [], 'bronc': [], 'dysp': ['bronc', 'e...  -2235.024
# 53   {'asia': [], 'bronc': [], 'dysp': ['bronc', 'e... -22193.508
# 74   {'asia': [], 'bronc': [], 'dysp': ['bronc', 'e... -22193.508
#
#                                          dp_parent_map  SHD
# 64   {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    4
# 65   {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    4
# 104  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    6
# 105  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    6
# 108  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...   11
# 117  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...   11
# 130  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    6
# 138  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    4
# 176  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...   11
# 45   {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...   10
# 73   {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    8
# 84   {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    3
# 88   {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    3
# 101  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    8
# 116  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    3
# 125  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    8
# 153  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...   10
# 161  {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...   10
# 53   {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    6
# 74   {'asia': [], 'bronc': ['smoke'], 'dysp': ['bro...    3

# %% [markdown]
# Make k and l ints

# %%
approx_df["k"] = approx_df["k"].astype(int)
approx_df["l"] = approx_df["l"].astype(int)

# %% [markdown]
# Plots comparing scores to upper bound

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) Aggregate over seeds
df_agg = (
    approx_df.groupby(["num_samples", "network", "k", "l"], as_index=False)
      .agg(
          score=("score", "mean"),
          dp_score=("dp_score", "mean"),
          theoretical_upper_bound=("theoretical_upper_bound", "mean"),
          naive_upper_bound=("naive_upper_bound", "mean"),
      )
)

# 2) Loop over sample sizes + approximation ratios
for (n, k, l), sub in df_agg.groupby(["num_samples", "k", "l"]):
    
    sub = sub.sort_values("network")

    x = np.arange(len(sub))
    width = 0.18  # slightly smaller so 4 bars fit well

    plt.figure(figsize=(7, 4))

    # Nice symmetric offsets for 4 bars
    plt.bar(x - 1.5*width, sub["score"], width, label="Approx score")
    plt.bar(x - 0.5*width, sub["dp_score"], width, label="DP (optimal)")
    plt.bar(x + 0.5*width, sub["theoretical_upper_bound"], width, label="Theoretical upper bound")
    plt.bar(x + 1.5*width, sub["naive_upper_bound"], width, label="Naive upper bound")

    plt.xticks(x, sub["network"], rotation=30, ha="right")
    plt.ylabel("Score")
    plt.title(f"Scores per network (n={n}, k={k}, l={l})")
    plt.legend(fontsize=7)
    plt.tight_layout()

    # Save figure
    outfile = root / f"experiments/plots/plot_scores_n{n}_k{k}_l{l}.png"
    plt.savefig(outfile, dpi=200, bbox_inches="tight")
    plt.close()

# %% [markdown]
# Plot comparing SHD

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) Aggregate over seeds (include SHD)
df_agg = (
    approx_df.groupby(["num_samples", "network", "k", "l"], as_index=False)
             .agg(
                 score=("score", "mean"),
                 dp_score=("dp_score", "mean"),
                 upper_bound=("theoretical_upper_bound", "mean"),
                 SHD=("SHD", "mean"),
             )
)

# 2) One plot per sample size, bars = (k,l) configs, x = network, y = SHD
for n, sub in df_agg.groupby("num_samples"):
    # Pivot so each (k,l) becomes a separate series per network
    pivot = sub.pivot(index="network", columns=["k", "l"], values="SHD")

    # Ensure deterministic order
    pivot = pivot.sort_index()
    networks = pivot.index.to_list()
    configs = list(pivot.columns)  # list of (k, l) tuples

    x = np.arange(len(networks))
    num_cfgs = len(configs)
    width = 0.8 / num_cfgs  # total width ~0.8 of the tick

    plt.figure(figsize=(7, 4))

    for i, (k, l) in enumerate(configs):
        # Center the group of bars around each x
        offsets = x + (i - (num_cfgs - 1) / 2) * width
        shd_vals = pivot[(k, l)].values

        plt.bar(
            offsets,
            shd_vals,
            width,
            label=f"k={int(k)}, l={int(l)}"
        )

    plt.xticks(x, networks, rotation=30, ha="right")
    plt.ylabel("Mean SHD (over seeds)")
    plt.title(f"SHD per network for different (k, l) (n={n})")
    plt.legend(fontsize=7, title="Config")
    plt.tight_layout()

    outfile = root / f"experiments/plots/plot_shd_n{n}.png"
    plt.savefig(outfile, dpi=200, bbox_inches="tight")
    plt.close()

    print(f"Saved: {outfile}")
# Out:
# Saved: /home/aurora/source/repos/bn-structure-learning/experiments/plots/plot_shd_n100.png
# Saved: /home/aurora/source/repos/bn-structure-learning/experiments/plots/plot_shd_n1000.png
# Saved: /home/aurora/source/repos/bn-structure-learning/experiments/plots/plot_shd_n10000.png

# %% [markdown]
# Create one df for each network

# %%
# make one df per network
network_dfs = {}
for network in approx_df["network"].unique():
    network_dfs[network] = approx_df[approx_df["network"] == network].drop(columns=["network"])

# %% [markdown]
# #

# %%
asia_df = network_dfs["asia"]

# %% [markdown]
# Write pandas table to latex

# %%
column_order = [
    "num_samples",
    "seed",
    "l",
    "k",
    "runtime",
    "score",
    "dp_score",
    "theoretical_upper_bound",
    "SHD",
]

# %%
# Sort globally before grouping
approx_df = approx_df.sort_values(["seed", "num_samples", "k"])

for net, df_net in approx_df.groupby("network"):
    print(f"% --- {net} ---")

    df_print = df_net.drop(columns=["network", "parent_map", "dp_parent_map", "num_vars"])

    df_print = df_print[column_order]

    # dynamically create column format string
    colfmt = "r" * len(df_print.columns)

    # generate the tabular
    tabular = df_print.to_latex(
        index=False,
        float_format="%.3f",
        column_format=colfmt,
        escape=False,
    )

    # wrap in table + resizebox
    print(
f"""\\begin{{table}}[H]
\\centering
\\scriptsize
\\caption{{Approximation algorithm vs DP on the {net} network.}}
\\label{{tab:approx_vs_dp_{net}}}
\\resizebox{{\\textwidth}}{{!}}{{%
{tabular}
}}
\\end{{table}}

"""
    )
# Out:
# % --- asia ---
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Approximation algorithm vs DP on the asia network.}
# \label{tab:approx_vs_dp_asia}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{rrrrrrrrr}
# \toprule
# num_samples & seed & l & k & runtime & score & dp_score & theoretical_upper_bound & SHD \\
# \midrule
# 100 & 42 & 2 & 3 & 0.006 & -252.923 & -251.306 & -92.995 & 6 \\
# 100 & 42 & 2 & 4 & 0.004 & -252.923 & -251.306 & 66.933 & 4 \\
# 100 & 42 & 1 & 5 & 0.002 & -256.725 & -251.306 & 1007.490 & 11 \\
# 1000 & 42 & 2 & 3 & 0.010 & -2238.429 & -2235.024 & -573.288 & 8 \\
# 1000 & 42 & 2 & 4 & 0.006 & -2235.024 & -2235.024 & 1098.663 & 3 \\
# 1000 & 42 & 1 & 5 & 0.003 & -2241.466 & -2235.024 & 11067.515 & 10 \\
# 10000 & 42 & 2 & 3 & 0.010 & -22198.112 & -22193.508 & -5556.137 & 8 \\
# 10000 & 42 & 2 & 4 & 0.007 & -22193.508 & -22193.508 & 11095.047 & 3 \\
# 10000 & 42 & 1 & 5 & 0.008 & -22202.566 & -22193.508 & 110915.416 & 6 \\
# 100 & 43 & 2 & 3 & 0.005 & -252.923 & -251.306 & -92.995 & 6 \\
# 100 & 43 & 2 & 4 & 0.003 & -252.923 & -251.306 & 66.933 & 4 \\
# 100 & 43 & 1 & 5 & 0.001 & -256.725 & -251.306 & 1007.490 & 11 \\
# 1000 & 43 & 2 & 3 & 0.005 & -2238.429 & -2235.024 & -573.288 & 8 \\
# 1000 & 43 & 2 & 4 & 0.004 & -2235.024 & -2235.024 & 1098.663 & 3 \\
# 1000 & 43 & 1 & 5 & 0.002 & -2241.466 & -2235.024 & 11067.515 & 10 \\
# 10000 & 43 & 2 & 3 & 0.008 & -22198.112 & -22193.508 & -5556.137 & 8 \\
# 10000 & 43 & 2 & 4 & 0.005 & -22193.508 & -22193.508 & 11095.047 & 3 \\
# 10000 & 43 & 1 & 5 & 0.003 & -22202.566 & -22193.508 & 110915.416 & 6 \\
# 100 & 44 & 2 & 3 & 0.006 & -252.923 & -251.306 & -92.995 & 6 \\
# 100 & 44 & 2 & 4 & 0.011 & -252.923 & -251.306 & 66.933 & 4 \\
# 100 & 44 & 1 & 5 & 0.004 & -256.725 & -251.306 & 1007.490 & 11 \\
# 1000 & 44 & 2 & 3 & 0.011 & -2238.429 & -2235.024 & -573.288 & 8 \\
# 1000 & 44 & 2 & 4 & 0.008 & -2235.024 & -2235.024 & 1098.663 & 3 \\
# 1000 & 44 & 1 & 5 & 0.003 & -2241.466 & -2235.024 & 11067.515 & 10 \\
# 10000 & 44 & 2 & 3 & 0.006 & -22198.112 & -22193.508 & -5556.137 & 8 \\
# 10000 & 44 & 2 & 4 & 0.007 & -22193.508 & -22193.508 & 11095.047 & 3 \\
# 10000 & 44 & 1 & 5 & 0.002 & -22202.566 & -22193.508 & 110915.416 & 6 \\
# \bottomrule
# \end{tabular}
#
# }
# \end{table}
#
#
# % --- cancer ---
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Approximation algorithm vs DP on the cancer network.}
# \label{tab:approx_vs_dp_cancer}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{rrrrrrrrr}
# \toprule
# num_samples & seed & l & k & runtime & score & dp_score & theoretical_upper_bound & SHD \\
# \midrule
# 100 & 42 & 2 & 3 & 0.001 & -219.777 & -219.777 & -167.191 & 4 \\
# 100 & 42 & 2 & 4 & 0.001 & -219.777 & -219.777 & -114.606 & 4 \\
# 100 & 42 & 1 & 5 & 0.001 & -219.777 & -219.777 & 200.907 & 4 \\
# 1000 & 42 & 2 & 3 & 0.001 & -2146.611 & -2146.611 & -1663.531 & 5 \\
# 1000 & 42 & 2 & 4 & 0.001 & -2146.611 & -2146.611 & -1180.450 & 5 \\
# 1000 & 42 & 1 & 5 & 0.001 & -2146.611 & -2146.611 & 1718.034 & 5 \\
# 10000 & 42 & 2 & 3 & 0.001 & -20936.911 & -20936.911 & -15882.501 & 0 \\
# 10000 & 42 & 2 & 4 & 0.001 & -20936.911 & -20936.911 & -10828.090 & 0 \\
# 10000 & 42 & 1 & 5 & 0.001 & -20940.605 & -20936.911 & 19479.901 & 4 \\
# 100 & 43 & 2 & 3 & 0.001 & -219.777 & -219.777 & -167.191 & 4 \\
# 100 & 43 & 2 & 4 & 0.001 & -219.777 & -219.777 & -114.606 & 4 \\
# 100 & 43 & 1 & 5 & 0.001 & -219.777 & -219.777 & 200.907 & 4 \\
# 1000 & 43 & 2 & 3 & 0.001 & -2146.611 & -2146.611 & -1663.531 & 5 \\
# 1000 & 43 & 2 & 4 & 0.001 & -2146.611 & -2146.611 & -1180.450 & 5 \\
# 1000 & 43 & 1 & 5 & 0.001 & -2146.611 & -2146.611 & 1718.034 & 5 \\
# 10000 & 43 & 2 & 3 & 0.001 & -20936.911 & -20936.911 & -15882.501 & 0 \\
# 10000 & 43 & 2 & 4 & 0.001 & -20936.911 & -20936.911 & -10828.090 & 0 \\
# 10000 & 43 & 1 & 5 & 0.001 & -20940.605 & -20936.911 & 19479.901 & 4 \\
# 100 & 44 & 2 & 3 & 0.001 & -219.777 & -219.777 & -167.191 & 4 \\
# 100 & 44 & 2 & 4 & 0.001 & -219.777 & -219.777 & -114.606 & 4 \\
# 100 & 44 & 1 & 5 & 0.001 & -219.777 & -219.777 & 200.907 & 4 \\
# 1000 & 44 & 2 & 3 & 0.001 & -2146.611 & -2146.611 & -1663.531 & 5 \\
# 1000 & 44 & 2 & 4 & 0.001 & -2146.611 & -2146.611 & -1180.450 & 5 \\
# 1000 & 44 & 1 & 5 & 0.001 & -2146.611 & -2146.611 & 1718.034 & 5 \\
# 10000 & 44 & 2 & 3 & 0.001 & -20936.911 & -20936.911 & -15882.501 & 0 \\
# 10000 & 44 & 2 & 4 & 0.001 & -20936.911 & -20936.911 & -10828.090 & 0 \\
# 10000 & 44 & 1 & 5 & 0.001 & -20940.605 & -20936.911 & 19479.901 & 4 \\
# \bottomrule
# \end{tabular}
#
# }
# \end{table}
#
#
# % --- earthquake ---
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Approximation algorithm vs DP on the earthquake network.}
# \label{tab:approx_vs_dp_earthquake}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{rrrrrrrrr}
# \toprule
# num_samples & seed & l & k & runtime & score & dp_score & theoretical_upper_bound & SHD \\
# \midrule
# 100 & 42 & 2 & 3 & 0.001 & -64.285 & -64.285 & -9.401 & 7 \\
# 100 & 42 & 2 & 4 & 0.003 & -64.285 & -64.285 & 45.484 & 7 \\
# 100 & 42 & 1 & 5 & 0.001 & -64.285 & -64.285 & 374.790 & 5 \\
# 1000 & 42 & 2 & 3 & 0.001 & -415.992 & -415.992 & -68.773 & 2 \\
# 1000 & 42 & 2 & 4 & 0.001 & -415.992 & -415.992 & 278.445 & 2 \\
# 1000 & 42 & 1 & 5 & 0.001 & -415.992 & -415.992 & 2361.756 & 4 \\
# 10000 & 42 & 2 & 3 & 0.002 & -4479.389 & -4475.044 & -668.214 & 7 \\
# 10000 & 42 & 2 & 4 & 0.007 & -4479.389 & -4475.044 & 3142.961 & 5 \\
# 10000 & 42 & 1 & 5 & 0.001 & -4479.389 & -4475.044 & 26010.009 & 5 \\
# 100 & 43 & 2 & 3 & 0.001 & -64.285 & -64.285 & -9.401 & 7 \\
# 100 & 43 & 2 & 4 & 0.001 & -64.285 & -64.285 & 45.484 & 7 \\
# 100 & 43 & 1 & 5 & 0.001 & -64.285 & -64.285 & 374.790 & 5 \\
# 1000 & 43 & 2 & 3 & 0.001 & -415.992 & -415.992 & -68.773 & 2 \\
# 1000 & 43 & 2 & 4 & 0.001 & -415.992 & -415.992 & 278.445 & 2 \\
# 1000 & 43 & 1 & 5 & 0.001 & -415.992 & -415.992 & 2361.756 & 4 \\
# 10000 & 43 & 2 & 3 & 0.001 & -4479.389 & -4475.044 & -668.214 & 7 \\
# 10000 & 43 & 2 & 4 & 0.001 & -4479.389 & -4475.044 & 3142.961 & 5 \\
# 10000 & 43 & 1 & 5 & 0.001 & -4479.389 & -4475.044 & 26010.009 & 5 \\
# 100 & 44 & 2 & 3 & 0.001 & -64.285 & -64.285 & -9.401 & 7 \\
# 100 & 44 & 2 & 4 & 0.001 & -64.285 & -64.285 & 45.484 & 7 \\
# 100 & 44 & 1 & 5 & 0.001 & -64.285 & -64.285 & 374.790 & 5 \\
# 1000 & 44 & 2 & 3 & 0.001 & -415.992 & -415.992 & -68.773 & 2 \\
# 1000 & 44 & 2 & 4 & 0.001 & -415.992 & -415.992 & 278.445 & 2 \\
# 1000 & 44 & 1 & 5 & 0.001 & -415.992 & -415.992 & 2361.756 & 4 \\
# 10000 & 44 & 2 & 3 & 0.001 & -4479.389 & -4475.044 & -668.214 & 7 \\
# 10000 & 44 & 2 & 4 & 0.001 & -4479.389 & -4475.044 & 3142.961 & 5 \\
# 10000 & 44 & 1 & 5 & 0.001 & -4479.389 & -4475.044 & 26010.009 & 5 \\
# \bottomrule
# \end{tabular}
#
# }
# \end{table}
#
#
# % --- sachs ---
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Approximation algorithm vs DP on the sachs network.}
# \label{tab:approx_vs_dp_sachs}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{rrrrrrrrr}
# \toprule
# num_samples & seed & l & k & runtime & score & dp_score & theoretical_upper_bound & SHD \\
# \midrule
# 100 & 42 & 2 & 3 & 0.048 & -869.895 & -869.895 & -684.999 & 19 \\
# 100 & 42 & 2 & 4 & 0.041 & -878.140 & -869.895 & -516.592 & 13 \\
# 100 & 42 & 1 & 5 & 0.004 & -878.493 & -869.895 & 566.284 & 23 \\
# 1000 & 42 & 2 & 3 & 0.033 & -7629.010 & -7629.010 & -5501.233 & 14 \\
# 1000 & 42 & 2 & 4 & 0.021 & -7629.010 & -7629.010 & -3373.455 & 4 \\
# 1000 & 42 & 1 & 5 & 0.005 & -7674.371 & -7629.010 & 9166.408 & 17 \\
# 10000 & 42 & 2 & 3 & 0.047 & -72562.356 & -72562.356 & -50053.768 & 6 \\
# 10000 & 42 & 2 & 4 & 0.029 & -72562.356 & -72562.356 & -27545.180 & 2 \\
# 10000 & 42 & 1 & 5 & 0.007 & -72713.733 & -72562.356 & 106749.461 & 15 \\
# 100 & 43 & 2 & 3 & 0.027 & -869.895 & -869.895 & -684.999 & 19 \\
# 100 & 43 & 2 & 4 & 0.020 & -878.140 & -869.895 & -516.592 & 13 \\
# 100 & 43 & 1 & 5 & 0.003 & -878.493 & -869.895 & 566.284 & 23 \\
# 1000 & 43 & 2 & 3 & 0.030 & -7629.010 & -7629.010 & -5501.233 & 14 \\
# 1000 & 43 & 2 & 4 & 0.020 & -7629.010 & -7629.010 & -3373.455 & 4 \\
# 1000 & 43 & 1 & 5 & 0.004 & -7674.371 & -7629.010 & 9166.408 & 17 \\
# 10000 & 43 & 2 & 3 & 0.038 & -72562.356 & -72562.356 & -50053.768 & 6 \\
# 10000 & 43 & 2 & 4 & 0.029 & -72562.356 & -72562.356 & -27545.180 & 2 \\
# 10000 & 43 & 1 & 5 & 0.007 & -72713.733 & -72562.356 & 106749.461 & 15 \\
# 100 & 44 & 2 & 3 & 0.042 & -869.895 & -869.895 & -684.999 & 19 \\
# 100 & 44 & 2 & 4 & 0.016 & -878.140 & -869.895 & -516.592 & 13 \\
# 100 & 44 & 1 & 5 & 0.006 & -878.493 & -869.895 & 566.284 & 23 \\
# 1000 & 44 & 2 & 3 & 0.045 & -7629.010 & -7629.010 & -5501.233 & 14 \\
# 1000 & 44 & 2 & 4 & 0.026 & -7629.010 & -7629.010 & -3373.455 & 4 \\
# 1000 & 44 & 1 & 5 & 0.005 & -7674.371 & -7629.010 & 9166.408 & 17 \\
# 10000 & 44 & 2 & 3 & 0.060 & -72562.356 & -72562.356 & -50053.768 & 6 \\
# 10000 & 44 & 2 & 4 & 0.037 & -72562.356 & -72562.356 & -27545.180 & 2 \\
# 10000 & 44 & 1 & 5 & 0.007 & -72713.733 & -72562.356 & 106749.461 & 15 \\
# \bottomrule
# \end{tabular}
#
# }
# \end{table}
#
#
# % --- survey ---
# \begin{table}[H]
# \centering
# \scriptsize
# \caption{Approximation algorithm vs DP on the survey network.}
# \label{tab:approx_vs_dp_survey}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{rrrrrrrrr}
# \toprule
# num_samples & seed & l & k & runtime & score & dp_score & theoretical_upper_bound & SHD \\
# \midrule
# 100 & 42 & 2 & 3 & 0.001 & -423.143 & -423.143 & -312.570 & 6 \\
# 100 & 42 & 2 & 4 & 0.002 & -423.143 & -423.143 & -201.996 & 6 \\
# 100 & 42 & 1 & 5 & 0.001 & -423.143 & -423.143 & 461.444 & 6 \\
# 1000 & 42 & 2 & 3 & 0.001 & -4033.283 & -4033.283 & -2916.633 & 8 \\
# 1000 & 42 & 2 & 4 & 0.002 & -4033.283 & -4033.283 & -1799.983 & 8 \\
# 1000 & 42 & 1 & 5 & 0.001 & -4033.283 & -4033.283 & 4899.915 & 6 \\
# 10000 & 42 & 2 & 3 & 0.001 & -39573.574 & -39569.183 & -28468.930 & 4 \\
# 10000 & 42 & 2 & 4 & 0.002 & -39573.574 & -39569.183 & -17364.285 & 4 \\
# 10000 & 42 & 1 & 5 & 0.001 & -39573.574 & -39569.183 & 49263.582 & 4 \\
# 100 & 43 & 2 & 3 & 0.001 & -423.143 & -423.143 & -312.570 & 6 \\
# 100 & 43 & 2 & 4 & 0.001 & -423.143 & -423.143 & -201.996 & 6 \\
# 100 & 43 & 1 & 5 & 0.001 & -423.143 & -423.143 & 461.444 & 6 \\
# 1000 & 43 & 2 & 3 & 0.001 & -4033.283 & -4033.283 & -2916.633 & 8 \\
# 1000 & 43 & 2 & 4 & 0.001 & -4033.283 & -4033.283 & -1799.983 & 8 \\
# 1000 & 43 & 1 & 5 & 0.001 & -4033.283 & -4033.283 & 4899.915 & 6 \\
# 10000 & 43 & 2 & 3 & 0.003 & -39573.574 & -39569.183 & -28468.930 & 4 \\
# 10000 & 43 & 2 & 4 & 0.002 & -39573.574 & -39569.183 & -17364.285 & 4 \\
# 10000 & 43 & 1 & 5 & 0.001 & -39573.574 & -39569.183 & 49263.582 & 4 \\
# 100 & 44 & 2 & 3 & 0.001 & -423.143 & -423.143 & -312.570 & 6 \\
# 100 & 44 & 2 & 4 & 0.002 & -423.143 & -423.143 & -201.996 & 6 \\
# 100 & 44 & 1 & 5 & 0.001 & -423.143 & -423.143 & 461.444 & 6 \\
# 1000 & 44 & 2 & 3 & 0.002 & -4033.283 & -4033.283 & -2916.633 & 8 \\
# 1000 & 44 & 2 & 4 & 0.002 & -4033.283 & -4033.283 & -1799.983 & 8 \\
# 1000 & 44 & 1 & 5 & 0.001 & -4033.283 & -4033.283 & 4899.915 & 6 \\
# 10000 & 44 & 2 & 3 & 0.003 & -39573.574 & -39569.183 & -28468.930 & 4 \\
# 10000 & 44 & 2 & 4 & 0.002 & -39573.574 & -39569.183 & -17364.285 & 4 \\
# 10000 & 44 & 1 & 5 & 0.001 & -39573.574 & -39569.183 & 49263.582 & 4 \\
# \bottomrule
# \end{tabular}
#
# }
# \end{table}

# %% [markdown]
# Generate network visualizations

# %%
from pgmpy.models import DiscreteBayesianNetwork

def draw_bn(pm, filename="bn.png"):
    # Convert pm into edge list
    edges = [(parent, child) for child, parents in pm.items() for parent in parents]
    bn = DiscreteBayesianNetwork(edges)

    # Convert model into pygraphviz object
    model_graphviz = bn.to_graphviz()

    # Plot the model.
    model_graphviz.draw(f"plots/{filename}", prog="dot")

# %%
asia = network_dfs["asia"]

# %%
for row_idx, row in asia.iterrows():
    k = row["k"]
    l = row["l"]
    seed = row["seed"]
    num_samples = row["num_samples"]
    filename = f"asia_k{k}_l{l}_seed{seed}_samples{num_samples}.png"
    draw_bn(row["parent_map"], filename=filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 7
#       5 num_samples = row["num_samples"]
#       6 filename = f"asia_k{k}_l{l}_seed{seed}_samples{num_samples}.png"
# ----> 7 draw_bn(row["parent_map"], filename=filename)
#
# Cell In[18], line 12, in draw_bn(pm, filename)
#       9 model_graphviz = bn.to_graphviz()
#      11 # Plot the model.
# ---> 12 model_graphviz.draw(f"plots/{filename}", prog="dot")
#
# File ~/source/repos/bn-structure-learning/.venv/lib/python3.11/site-packages/pygraphviz/agraph.py:1611, in AGraph.draw(self, path, format, prog, args)
#    1608 data = self._run_prog(prog, args)
#    1610 if path is not None:
# -> 1611     fh = self._get_fh(path, "w+b")
#    1612     fh.write(data)
#    1613     if isinstance(path, str | pathlib.Path):
#
# File ~/source/repos/bn-structure-learning/.venv/lib/python3.11/site-packages/pygraphviz/agraph.py:1787, in AGraph._get_fh(self, path, mode)
#    1785         fh = os.popen("bzcat " + path)  # probably not portable
#    1786     else:
# -> 1787         fh = open(path, mode=mode)
#    1788 elif hasattr(path, "write"):
#    1789     # Note, mode of file handle is unchanged.
#    1790     fh = path
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plots/asia_k5_l1_seed44_samples1000.png'
